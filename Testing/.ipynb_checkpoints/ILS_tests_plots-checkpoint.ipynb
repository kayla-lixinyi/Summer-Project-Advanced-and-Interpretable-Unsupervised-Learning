# %%
import sys 
sys.path.append("..")
import numpy as np
from ILS_class import ILS
import matplotlib.pyplot as plt
import pandas as pd

# %%
artSet =  pd.read_csv(r"Artificial Data sets\target.csv", header=1)

testILS = ILS(min_cluster_size = 100, plot_rmin = True)
testILS.fit(artSet)

# %%
testILS.plot_labels()

# %%
testILS = ILS(min_cluster_size = 300, plot_rmin = True) # larger minimum cluster size
testILS.fit(artSet)

# %%
testILS.plot_labels()

# %%
test1 = pd.read_csv(r"Artificial Data sets\zelnik1.csv", header=1)
testILS = ILS(min_cluster_size = 50, plot_rmin = True)
testILS_n = ILS(n_clusters = 3, plot_rmin = True)
testILS.fit(test1)
testILS_n.fit(test1)

# %%
#encountering problems withing differing cluster size
testILS.plot_labels()
testILS_n.plot_labels()

# %%
test2 = pd.read_csv(r"Artificial Data sets\zelnik6.csv", header=1)
testILS = ILS(min_cluster_size = 50, plot_rmin = True)
testILS.fit(test2)

# %%
testILS.plot_labels()
